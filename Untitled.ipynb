# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.display import display
import pandas as pd
from pathlib import Path
import numpy as np
from PIL import Image
test_data = np.random.beta(size=[100,100,3], a=1,b=1)
plt.imshow(test_data)

# %%
img = Image.open('C:/Users/lewa1612/Desktop/indeks.png')
img_size = img.size
print('Image size is: {} '.format(img_size))
# Out:
# Image size is: (100, 100)
